# %%
# %sql
DESCRIBE EXTERNAL LOCATION el_bronze;

# %%
# %sql

CREATE VOLUME main.default.bronze_adventureworks

# %%
df_aw2 = spark.read.parquet(
    "/Volumes/main/default/bronze_adventureworks/bronze/adventureworks2/"
)

df_aw2.display()

# %%
# %sql
DESCRIBE VOLUME main.default.bronze_adventureworks;

# %%
# %sql
DROP VOLUME main.default.bronze_adventureworks;

# %%
# %sql

CREATE EXTERNAL VOLUME main.default.bronze_adventureworks
LOCATION 'abfss://fabmigation1@synpasetofabric.dfs.core.windows.net/bronze';
